# %% [markdown]
# # Investigate Uncertainty Change
#
# **Obs0_var** is the summation of diagnal of covariance matrix.
#
# **Obs0_cov** is the summation of up triangle of covariance matrix.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### HalfCheetah-v2
# #### UD3: no_delay_train + 10000 start_steps

# %%
data_path = "../../data/2019-03-31_ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train/2019-03-31_19-40-02-ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_s3/uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()

# %%
#### UD3: no_delay_train + 10000 start_steps

# %%
data_path = "../../data/2019-04-01_ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_with_start_steps/2019-04-01_11-02-55-ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_with_start_steps_s3/uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()

# %% [markdown]
# #### UD3: no_delay_train + 50000 start_steps

# %%
data_path = "../../data/2019-04-01_ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_with_start_steps_50000/2019-04-01_20-54-44-ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_with_start_steps_50000_s3/uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()

# %% [markdown]
# #### UD3: no_delay_train + no_start_steps

# %%
data_path = "../../data/2019-04-01_ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_without_start_steps/2019-04-01_00-30-36-ud3_HalfCheetah_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_without_start_steps_s3/uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()

# %% [markdown]
# ### Uncertainty based on target policy rather than online policy

# %%
data_path = r"C:\Users\pc-admin\Github Repos\spinningup\data\2019-04-04_ud3_unc_based_on_targ_policy\2019-04-04_15-14-14-ud3_unc_based_on_targ_policy_s3\uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
#     ax1.scatter(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
#     ax2.scatter(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()

# %% [markdown]
# ### InvertedPendulum-v2

# %%
data_path = "../../data/2019-04-02_ud3_InvertedPendulum_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_with_start_steps/2019-04-02_01-31-10-ud3_InvertedPendulum_3S_2L_200Ep_1Drop_GSP_1Con_0Low_no_delay_train_with_start_steps_s3/uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()


### UD3: no_delay_train + no_start_steps

# %% [markdown]
# ## Gaussian Observation Sample

# %%
data_path = r"C:\Users\pc-admin\Github Repos\spinningup\data\2019-04-09_ud3_GOS_Unc\2019-04-09_00-52-59-ud3_GOS_Unc_s3\obs_sample_uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()


### UD3: no_delay_train + no_start_steps

# %%
    

data_path = r"C:\Users\pc-admin\Github Repos\spinningup\data\2019-04-09_ud3_GOS_Unc_test\2019-04-09_10-36-50-ud3_GOS_Unc_test_s3\obs_sample_uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()


### UD3: no_delay_train + no_start_steps

# %%
data_path = r"C:\Users\pc-admin\Github Repos\spinningup\data\2019-04-10_ud3_GOS_Unc_test_0_5_std\2019-04-10_00-01-34-ud3_GOS_Unc_test_0_5_std_s3\obs_sample_uncertainty.txt"
data_df = pd.read_csv(data_path,  sep='\t')

for i in range(10):
#     fig, ax = plt.subplots()
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4) ,sharey=True)
    ax1.plot(np.arange(data_df.shape[0]), data_df['Obs{}_var'.format(i)])
    ax1.set_title('Obs{}_var'.format(i))
    
    ax2.plot(np.arange(data_df.shape[0]), data_df['Obs{}_cov'.format(i)])
    ax2.set_title('Obs{}_cov'.format(i))
    
    plt.tight_layout()


### UD3: no_delay_train + no_start_steps
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f035cf7bb7e> in <module>
#       2
#       3 data_path = r"C:\Users\pc-admin\Github Repos\spinningup\data\2019-04-10_ud3_GOS_Unc_test_0_5_std\2019-04-10_00-01-34-ud3_GOS_Unc_test_0_5_std_s3\obs_sample_uncertainty.txt"
# ----> 4 data_df = pd.read_csv(data_path,  sep='\t')
#       5
#       6 for i in range(10):
#
# NameError: name 'pd' is not defined
