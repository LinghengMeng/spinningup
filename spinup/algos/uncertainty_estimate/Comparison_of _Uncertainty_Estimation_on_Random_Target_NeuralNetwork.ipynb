# %% [markdown]
# # Comparison of  Uncertainty Estimation on Random Target Neural Network

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# path = r"C:\Users\pc-admin\Github Repos\spinup_data\2019-05-23_uncertainty_estimate_x15_y5_linearOutput\2019-05-23_17-29-18-uncertainty_estimate_x15_y5_linearOutput_s3\progress.txt"

# path = r"C:\Users\pc-admin\Github Repos\spinup_data\2019-05-27_uncertainty_estimate\2019-05-27_22-39-33-uncertainty_estimate_s3\progress.txt"

path = r"C:\Users\pc-admin\Github Repos\spinup_data\2019-05-28_uncertainty_estimate_10000Data_1000000TrainEp\2019-05-28_20-28-30-uncertainty_estimate_10000Data_1000000TrainEp_s3\progress.txt"

path = r"C:\Users\pc-admin\Github Repos\spinup_data\2019-05-28_uncertainty_estimate_10000Data_40000TrainEp\2019-05-28_22-54-39-uncertainty_estimate_10000Data_40000TrainEp_s3\progress.txt"

# With L2 regularization
path = r"C:\Users\pc-admin\Github Repos\spinup_data\2019-05-31_uncertainty_estimate_100000Data_100000TrainEp\2019-05-31_16-35-03-uncertainty_estimate_100000Data_100000TrainEp_s3\progress.txt"

# %%
cov_columns = ['lazy_ber_drop_mlp_postSample_cov_{}'.format(i) for i in range(25)]
data_df[cov_columns]
# Out:
#        lazy_ber_drop_mlp_postSample_cov_0  lazy_ber_drop_mlp_postSample_cov_1  \
# 0                            2.915779e-03                       -9.268986e-04
# 1                            6.444306e-03                        6.155767e-04
# 2                            5.864331e-03                       -4.878150e-04
# 3                            1.068393e-02                        7.297681e-04
# 4                            2.973302e-03                        7.385937e-04
# 5                            2.287152e-03                        3.664964e-04
# 6                            5.734572e-03                        7.852291e-04
# 7                            7.552693e-03                       -1.231465e-03
# 8                            1.031347e-02                       -8.714429e-04
# 9                            9.573007e-03                       -3.423618e-03
# 10                           8.088130e-03                       -1.266366e-03
# 11                           5.790096e-03                       -4.931000e-04
# 12                           5.472864e-03                       -2.127291e-03
# 13                           1.216811e-02                       -5.978113e-04
# 14                           1.271901e-03                       -4.091943e-04
# 15                           1.460762e-03                        1.868154e-04
# 16                           7.298120e-03                       -5.836226e-04
# 17                           9.482433e-04                        2.703712e-04
# 18                           9.019582e-03                       -2.033416e-03
# 19                           5.387381e-03                       -2.605025e-05
# 20                           4.033593e-03                       -1.360127e-04
# 21                           2.158424e-02                       -2.746723e-03
# 22                           4.031682e-03                        2.684990e-04
# 23                           1.281903e-05                        1.712094e-05
# 24                           1.798684e-02                       -1.261809e-03
# 25                           2.070916e-02                       -1.623770e-03
# 26                           3.784580e-03                       -7.174001e-04
# 27                           2.424543e-02                       -1.978596e-03
# 28                           5.221276e-05                        8.280957e-06
# 29                           3.572527e-02                       -1.698318e-03
# ...                                   ...                                 ...
# 99869                        0.000000e+00                        0.000000e+00
# 99870                        9.999940e-03                       -2.020790e-04
# 99871                        9.999999e-03                        9.589199e-03
# 99872                        1.542805e-01                        1.030284e-03
# 99873                        1.494368e-01                       -4.781842e-10
# 99874                        1.978862e-02                        5.256733e-04
# 99875                        5.625756e-02                        6.898251e-04
# 99876                        2.331050e-01                       -4.248260e-04
# 99877                        1.171431e-01                        0.000000e+00
# 99878                        0.000000e+00                        0.000000e+00
# 99879                        1.967696e-01                        1.330144e-02
# 99880                        0.000000e+00                        0.000000e+00
# 99881                        1.779392e-01                        0.000000e+00
# 99882                        2.150267e-05                        0.000000e+00
# 99883                        0.000000e+00                        0.000000e+00
# 99884                        4.102928e-09                        8.340705e-07
# 99885                        1.326369e-01                        0.000000e+00
# 99886                        9.375378e-03                        0.000000e+00
# 99887                        0.000000e+00                        0.000000e+00
# 99888                        1.574258e-02                        0.000000e+00
# 99889                        8.089540e-02                        1.088489e-09
# 99890                        6.590440e-11                        7.954156e-07
# 99891                        0.000000e+00                        0.000000e+00
# 99892                        0.000000e+00                        0.000000e+00
# 99893                        7.424121e-02                       -7.853142e-08
# 99894                        1.947951e-02                       -8.545684e-03
# 99895                        1.519543e-02                        0.000000e+00
# 99896                        0.000000e+00                        0.000000e+00
# 99897                        3.874202e-02                       -1.722004e-02
# 99898                        5.684342e-16                        0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_2  lazy_ber_drop_mlp_postSample_cov_3  \
# 0                           -2.529303e-04                        2.624344e-04
# 1                            8.527418e-04                        1.838171e-03
# 2                            3.620035e-04                       -2.289038e-04
# 3                           -1.801236e-04                        6.374950e-04
# 4                           -1.224309e-04                        1.955654e-04
# 5                           -1.363666e-05                        1.002797e-04
# 6                            5.525992e-05                       -5.289439e-04
# 7                           -1.831582e-05                        1.257129e-03
# 8                            3.140772e-04                       -9.754416e-04
# 9                           -1.887488e-04                        9.182020e-04
# 10                           1.166685e-04                        1.526065e-04
# 11                           2.439235e-05                        1.402854e-04
# 12                          -1.668597e-04                       -1.245121e-03
# 13                           9.687237e-05                        3.396200e-03
# 14                           9.711799e-06                        1.054685e-04
# 15                           3.486266e-05                        2.535677e-04
# 16                          -8.743281e-04                       -3.260877e-04
# 17                          -1.557704e-04                        4.387963e-05
# 18                           3.197333e-04                       -1.808552e-04
# 19                          -5.012964e-04                        1.990518e-03
# 20                           1.011649e-03                        2.139374e-04
# 21                          -7.460740e-05                       -3.657186e-03
# 22                          -7.008245e-04                        2.298410e-03
# 23                          -4.518754e-05                        3.573836e-05
# 24                           2.106176e-03                        4.889675e-03
# 25                          -8.827291e-04                        6.522289e-03
# 26                          -7.997564e-04                        2.876031e-03
# 27                           2.355599e-04                        2.899309e-03
# 28                          -1.963914e-05                        4.561980e-05
# 29                          -3.460857e-04                       -1.553389e-04
# ...                                   ...                                 ...
# 99869                        0.000000e+00                        0.000000e+00
# 99870                        0.000000e+00                        3.613493e-11
# 99871                        0.000000e+00                        0.000000e+00
# 99872                        4.964396e-03                       -5.936859e-03
# 99873                        0.000000e+00                        2.852806e-02
# 99874                        2.053464e-04                        4.126102e-03
# 99875                        0.000000e+00                        0.000000e+00
# 99876                        0.000000e+00                        0.000000e+00
# 99877                       -2.404643e-03                        1.115371e-02
# 99878                        0.000000e+00                        0.000000e+00
# 99879                       -2.918062e-03                        1.827307e-02
# 99880                        0.000000e+00                        0.000000e+00
# 99881                        6.635696e-03                        5.364570e-03
# 99882                       -1.821741e-05                        1.244084e-05
# 99883                        0.000000e+00                        0.000000e+00
# 99884                       -1.542667e-14                        0.000000e+00
# 99885                       -2.609133e-02                        0.000000e+00
# 99886                       -4.541129e-03                       -7.422276e-04
# 99887                        0.000000e+00                        0.000000e+00
# 99888                        0.000000e+00                        0.000000e+00
# 99889                       -3.776276e-02                       -1.566263e-02
# 99890                        0.000000e+00                       -4.887673e-16
# 99891                        0.000000e+00                        0.000000e+00
# 99892                        0.000000e+00                        0.000000e+00
# 99893                        4.645807e-08                        2.788396e-04
# 99894                        0.000000e+00                        5.692532e-04
# 99895                       -3.092858e-04                        3.915097e-04
# 99896                        0.000000e+00                        0.000000e+00
# 99897                        0.000000e+00                        3.994817e-04
# 99898                        0.000000e+00                        0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_4  lazy_ber_drop_mlp_postSample_cov_5  \
# 0                            5.954764e-04                       -9.268986e-04
# 1                            2.632841e-03                        6.155767e-04
# 2                            2.035582e-04                       -4.878150e-04
# 3                            1.930283e-04                        7.297681e-04
# 4                           -3.502922e-04                        7.385937e-04
# 5                           -2.053146e-04                        3.664964e-04
# 6                            9.535863e-05                        7.852291e-04
# 7                            1.885005e-05                       -1.231465e-03
# 8                            2.744437e-05                       -8.714429e-04
# 9                           -4.755455e-04                       -3.423618e-03
# 10                           3.117573e-06                       -1.266366e-03
# 11                           1.104327e-05                       -4.931000e-04
# 12                          -2.016882e-05                       -2.127291e-03
# 13                           5.372544e-06                       -5.978113e-04
# 14                          -8.878957e-06                       -4.091943e-04
# 15                           3.943588e-07                        1.868154e-04
# 16                          -8.989076e-07                       -5.836226e-04
# 17                          -2.972270e-05                        2.703712e-04
# 18                           8.489901e-06                       -2.033416e-03
# 19                           1.121654e-04                       -2.605025e-05
# 20                          -2.766518e-05                       -1.360127e-04
# 21                           1.067976e-05                       -2.746723e-03
# 22                          -1.957167e-05                        2.684990e-04
# 23                          -6.092467e-08                        1.712094e-05
# 24                          -8.519422e-07                       -1.261809e-03
# 25                           3.763911e-05                       -1.623770e-03
# 26                          -5.855175e-06                       -7.174001e-04
# 27                           2.501298e-06                       -1.978596e-03
# 28                          -2.991786e-06                        8.280957e-06
# 29                           6.216320e-06                       -1.698318e-03
# ...                                   ...                                 ...
# 99869                        0.000000e+00                        0.000000e+00
# 99870                        0.000000e+00                       -2.020790e-04
# 99871                        0.000000e+00                        9.589199e-03
# 99872                        0.000000e+00                        1.030284e-03
# 99873                        0.000000e+00                       -4.781842e-10
# 99874                        0.000000e+00                        5.256733e-04
# 99875                        0.000000e+00                        6.898251e-04
# 99876                        0.000000e+00                       -4.248260e-04
# 99877                       -3.342269e-09                        0.000000e+00
# 99878                        0.000000e+00                        0.000000e+00
# 99879                       -6.984142e-08                        1.330144e-02
# 99880                        0.000000e+00                        0.000000e+00
# 99881                        0.000000e+00                        0.000000e+00
# 99882                       -6.170026e-06                        0.000000e+00
# 99883                        0.000000e+00                        0.000000e+00
# 99884                        0.000000e+00                        8.340705e-07
# 99885                        5.669339e-08                        0.000000e+00
# 99886                        0.000000e+00                        0.000000e+00
# 99887                        0.000000e+00                        0.000000e+00
# 99888                        0.000000e+00                        0.000000e+00
# 99889                        0.000000e+00                        1.088489e-09
# 99890                       -5.833169e-11                        7.954156e-07
# 99891                        0.000000e+00                        0.000000e+00
# 99892                        0.000000e+00                        0.000000e+00
# 99893                        0.000000e+00                       -7.853142e-08
# 99894                       -4.513222e-03                       -8.545684e-03
# 99895                       -4.362732e-08                        0.000000e+00
# 99896                        0.000000e+00                        0.000000e+00
# 99897                        0.000000e+00                       -1.722004e-02
# 99898                        0.000000e+00                        0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_6  lazy_ber_drop_mlp_postSample_cov_7  \
# 0                            7.416664e-03                       -7.917661e-05
# 1                            5.331770e-03                       -5.141560e-04
# 2                            3.938245e-03                       -5.328587e-04
# 3                            9.642228e-03                       -3.509185e-04
# 4                            5.679603e-03                       -2.339413e-04
# 5                            6.378389e-03                       -6.805074e-04
# 6                            3.548689e-03                       -8.608225e-05
# 7                            5.616163e-03                       -6.132348e-05
# 8                            8.810762e-03                       -4.446000e-04
# 9                            7.487141e-03                        2.452039e-05
# 10                           4.423973e-03                       -3.062411e-04
# 11                           2.004764e-03                       -1.069493e-04
# 12                           1.376761e-02                        3.527460e-05
# 13                           1.385712e-03                       -1.007613e-04
# 14                           5.172296e-03                       -5.409670e-04
# 15                           3.048814e-03                       -6.283444e-05
# 16                           1.162000e-02                       -1.599695e-03
# 17                           1.047220e-02                       -1.216244e-03
# 18                           1.456751e-02                       -5.511379e-04
# 19                           2.346080e-03                       -4.475186e-04
# 20                           4.823207e-03                       -1.409835e-03
# 21                           1.016267e-02                       -7.716903e-05
# 22                           2.165055e-03                       -7.293076e-04
# 23                           1.619370e-02                       -2.720843e-03
# 24                           8.142991e-03                       -3.517512e-03
# 25                           4.590143e-03                       -8.360597e-05
# 26                           1.821559e-02                       -5.996638e-04
# 27                           1.225894e-02                       -8.555904e-04
# 28                           3.401938e-03                       -9.802977e-04
# 29                           2.625881e-03                       -2.607687e-04
# ...                                   ...                                 ...
# 99869                        9.999917e-03                        0.000000e+00
# 99870                        1.979755e-02                        0.000000e+00
# 99871                        4.522337e-02                        0.000000e+00
# 99872                        1.222573e-03                        2.434942e-03
# 99873                        3.552714e-17                        0.000000e+00
# 99874                        2.278806e-02                       -2.590632e-04
# 99875                        9.999532e-03                        0.000000e+00
# 99876                        2.337012e-01                        0.000000e+00
# 99877                        0.000000e+00                        0.000000e+00
# 99878                        2.106308e-11                        1.003023e-08
# 99879                        2.135455e-01                       -5.236995e-03
# 99880                        4.795780e-02                        0.000000e+00
# 99881                        0.000000e+00                        0.000000e+00
# 99882                        0.000000e+00                        0.000000e+00
# 99883                        4.165497e-02                        4.515497e-04
# 99884                        1.107600e-01                       -2.097830e-09
# 99885                        0.000000e+00                        0.000000e+00
# 99886                        0.000000e+00                        0.000000e+00
# 99887                        0.000000e+00                        0.000000e+00
# 99888                        0.000000e+00                        0.000000e+00
# 99889                        1.421085e-16                       -1.092235e-09
# 99890                        2.939248e-02                        0.000000e+00
# 99891                        0.000000e+00                        0.000000e+00
# 99892                        6.078868e-02                        2.000388e-03
# 99893                        6.802746e-11                       -4.459297e-11
# 99894                        5.292773e-02                        0.000000e+00
# 99895                        0.000000e+00                        0.000000e+00
# 99896                        4.793008e-02                        9.426632e-10
# 99897                        9.742222e-02                        0.000000e+00
# 99898                        0.000000e+00                        0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_8  lazy_ber_drop_mlp_postSample_cov_9  \
# 0                            1.818080e-03                       -6.010791e-04
# 1                            5.872799e-04                        5.001386e-07
# 2                            1.059069e-03                       -2.088172e-05
# 3                            8.121701e-04                       -7.246957e-05
# 4                            6.157537e-04                       -1.627311e-04
# 5                            4.034307e-04                       -1.980552e-04
# 6                            6.149313e-04                       -3.137577e-04
# 7                           -9.546620e-04                       -7.096050e-05
# 8                            2.318720e-04                       -1.972243e-05
# 9                            6.347260e-05                        1.107727e-04
# 10                           4.511095e-04                       -8.343809e-05
# 11                           7.108827e-04                       -7.743391e-06
# 12                           7.090903e-03                        8.005491e-06
# 13                          -8.465722e-04                       -8.825387e-06
# 14                           1.742822e-03                       -2.068452e-05
# 15                           6.930730e-04                        1.824856e-07
# 16                           9.184982e-04                       -2.936032e-08
# 17                          -1.371432e-03                       -1.399818e-05
# 18                          -1.102470e-04                       -2.044297e-05
# 19                          -1.899761e-03                       -5.095268e-05
# 20                           3.096124e-05                        1.183772e-05
# 21                           2.986646e-04                       -2.999344e-06
# 22                           1.774204e-03                       -3.400685e-05
# 23                           1.556753e-03                        7.552254e-07
# 24                          -1.277212e-03                       -5.290589e-06
# 25                           4.565628e-04                       -8.214693e-06
# 26                           1.222711e-04                       -1.770500e-05
# 27                          -5.465763e-03                       -2.434508e-06
# 28                           1.337593e-03                       -1.980095e-05
# 29                           8.890389e-05                       -3.803013e-06
# ...                                   ...                                 ...
# 99869                       -2.167433e-10                        0.000000e+00
# 99870                       -3.540155e-09                        0.000000e+00
# 99871                        0.000000e+00                        0.000000e+00
# 99872                       -3.799112e-03                        0.000000e+00
# 99873                        4.031015e-10                        0.000000e+00
# 99874                       -1.048860e-02                        0.000000e+00
# 99875                        0.000000e+00                        0.000000e+00
# 99876                        0.000000e+00                        0.000000e+00
# 99877                        0.000000e+00                        0.000000e+00
# 99878                       -1.359987e-08                        0.000000e+00
# 99879                       -5.158239e-03                       -5.192677e-08
# 99880                       -3.124054e-03                        0.000000e+00
# 99881                        0.000000e+00                        0.000000e+00
# 99882                        0.000000e+00                        0.000000e+00
# 99883                        0.000000e+00                        5.634921e-11
# 99884                        0.000000e+00                        0.000000e+00
# 99885                        0.000000e+00                        0.000000e+00
# 99886                        0.000000e+00                        0.000000e+00
# 99887                        0.000000e+00                        0.000000e+00
# 99888                        0.000000e+00                        0.000000e+00
# 99889                        3.456351e-11                        0.000000e+00
# 99890                       -1.806157e-11                       -7.040187e-07
# 99891                        0.000000e+00                        0.000000e+00
# 99892                        0.000000e+00                        0.000000e+00
# 99893                       -2.807561e-10                        0.000000e+00
# 99894                       -1.810392e-03                        8.500553e-03
# 99895                        0.000000e+00                        0.000000e+00
# 99896                        0.000000e+00                        0.000000e+00
# 99897                       -1.185524e-03                        0.000000e+00
# 99898                        0.000000e+00                        0.000000e+00
#
#        ...  lazy_ber_drop_mlp_postSample_cov_15  \
# 0      ...                         2.624344e-04
# 1      ...                         1.838171e-03
# 2      ...                        -2.289038e-04
# 3      ...                         6.374950e-04
# 4      ...                         1.955654e-04
# 5      ...                         1.002797e-04
# 6      ...                        -5.289439e-04
# 7      ...                         1.257129e-03
# 8      ...                        -9.754416e-04
# 9      ...                         9.182020e-04
# 10     ...                         1.526065e-04
# 11     ...                         1.402854e-04
# 12     ...                        -1.245121e-03
# 13     ...                         3.396200e-03
# 14     ...                         1.054685e-04
# 15     ...                         2.535677e-04
# 16     ...                        -3.260877e-04
# 17     ...                         4.387963e-05
# 18     ...                        -1.808552e-04
# 19     ...                         1.990518e-03
# 20     ...                         2.139374e-04
# 21     ...                        -3.657186e-03
# 22     ...                         2.298410e-03
# 23     ...                         3.573836e-05
# 24     ...                         4.889675e-03
# 25     ...                         6.522289e-03
# 26     ...                         2.876031e-03
# 27     ...                         2.899309e-03
# 28     ...                         4.561980e-05
# 29     ...                        -1.553389e-04
# ...    ...                                  ...
# 99869  ...                         0.000000e+00
# 99870  ...                         3.613493e-11
# 99871  ...                         0.000000e+00
# 99872  ...                        -5.936859e-03
# 99873  ...                         2.852806e-02
# 99874  ...                         4.126102e-03
# 99875  ...                         0.000000e+00
# 99876  ...                         0.000000e+00
# 99877  ...                         1.115371e-02
# 99878  ...                         0.000000e+00
# 99879  ...                         1.827307e-02
# 99880  ...                         0.000000e+00
# 99881  ...                         5.364570e-03
# 99882  ...                         1.244084e-05
# 99883  ...                         0.000000e+00
# 99884  ...                         0.000000e+00
# 99885  ...                         0.000000e+00
# 99886  ...                        -7.422276e-04
# 99887  ...                         0.000000e+00
# 99888  ...                         0.000000e+00
# 99889  ...                        -1.566263e-02
# 99890  ...                        -4.887673e-16
# 99891  ...                         0.000000e+00
# 99892  ...                         0.000000e+00
# 99893  ...                         2.788396e-04
# 99894  ...                         5.692532e-04
# 99895  ...                         3.915097e-04
# 99896  ...                         0.000000e+00
# 99897  ...                         3.994817e-04
# 99898  ...                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_16  \
# 0                             1.818080e-03
# 1                             5.872799e-04
# 2                             1.059069e-03
# 3                             8.121701e-04
# 4                             6.157537e-04
# 5                             4.034307e-04
# 6                             6.149313e-04
# 7                            -9.546620e-04
# 8                             2.318720e-04
# 9                             6.347260e-05
# 10                            4.511095e-04
# 11                            7.108827e-04
# 12                            7.090903e-03
# 13                           -8.465722e-04
# 14                            1.742822e-03
# 15                            6.930730e-04
# 16                            9.184982e-04
# 17                           -1.371432e-03
# 18                           -1.102470e-04
# 19                           -1.899761e-03
# 20                            3.096124e-05
# 21                            2.986646e-04
# 22                            1.774204e-03
# 23                            1.556753e-03
# 24                           -1.277212e-03
# 25                            4.565628e-04
# 26                            1.222711e-04
# 27                           -5.465763e-03
# 28                            1.337593e-03
# 29                            8.890389e-05
# ...                                    ...
# 99869                        -2.167433e-10
# 99870                        -3.540155e-09
# 99871                         0.000000e+00
# 99872                        -3.799112e-03
# 99873                         4.031015e-10
# 99874                        -1.048860e-02
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                         0.000000e+00
# 99878                        -1.359987e-08
# 99879                        -5.158239e-03
# 99880                        -3.124054e-03
# 99881                         0.000000e+00
# 99882                         0.000000e+00
# 99883                         0.000000e+00
# 99884                         0.000000e+00
# 99885                         0.000000e+00
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         3.456351e-11
# 99890                        -1.806157e-11
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                        -2.807561e-10
# 99894                        -1.810392e-03
# 99895                         0.000000e+00
# 99896                         0.000000e+00
# 99897                        -1.185524e-03
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_17  \
# 0                             8.700847e-04
# 1                             1.142589e-03
# 2                            -7.936179e-04
# 3                            -2.214025e-05
# 4                            -1.781571e-05
# 5                             2.803412e-04
# 6                             1.377639e-04
# 7                             2.734065e-05
# 8                            -1.269727e-04
# 9                            -1.347141e-05
# 10                           -7.995188e-05
# 11                           -1.345042e-05
# 12                            1.635510e-05
# 13                            6.708558e-05
# 14                            2.053545e-04
# 15                           -1.478295e-04
# 16                            1.039821e-04
# 17                            3.440632e-04
# 18                           -5.385656e-05
# 19                            4.244642e-04
# 20                            3.974878e-05
# 21                           -1.191733e-04
# 22                           -1.251771e-03
# 23                           -6.349597e-04
# 24                            1.317334e-03
# 25                           -1.122145e-04
# 26                           -1.133229e-03
# 27                            6.852282e-04
# 28                           -1.068836e-03
# 29                            1.343868e-05
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                        -1.944155e-02
# 99873                         0.000000e+00
# 99874                         2.071183e-03
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                        -2.482470e-02
# 99878                        -1.383828e-02
# 99879                        -7.155048e-03
# 99880                         0.000000e+00
# 99881                         6.077127e-04
# 99882                         5.001946e-04
# 99883                         0.000000e+00
# 99884                         0.000000e+00
# 99885                         0.000000e+00
# 99886                        -3.057513e-02
# 99887                        -4.398542e-02
# 99888                         0.000000e+00
# 99889                         7.370536e-03
# 99890                         0.000000e+00
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         1.660913e-10
# 99894                         0.000000e+00
# 99895                        -5.421336e-03
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_18  \
# 0                             8.790879e-03
# 1                             8.246521e-03
# 2                             2.603000e-03
# 3                             4.702974e-03
# 4                             6.068793e-04
# 5                             4.949822e-03
# 6                             4.597450e-03
# 7                             9.848064e-03
# 8                             5.561284e-03
# 9                             3.568670e-03
# 10                            5.331820e-04
# 11                            1.394683e-03
# 12                            1.668771e-02
# 13                            6.079735e-03
# 14                            6.802854e-03
# 15                            6.108250e-03
# 16                            1.248313e-03
# 17                            2.439431e-03
# 18                            2.869668e-04
# 19                            1.195577e-02
# 20                            1.444900e-04
# 21                            7.430194e-03
# 22                            1.289117e-02
# 23                            2.870827e-03
# 24                            2.862559e-02
# 25                            1.418793e-02
# 26                            1.872764e-02
# 27                            3.413648e-02
# 28                            3.103082e-03
# 29                            1.600787e-05
# ...                                    ...
# 99869                         4.604317e-14
# 99870                         1.278977e-15
# 99871                         0.000000e+00
# 99872                         3.238663e-02
# 99873                         1.888081e-01
# 99874                         1.523367e-01
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                         1.854982e-01
# 99878                         3.551384e-02
# 99879                         1.120675e-01
# 99880                         5.589572e-02
# 99881                         2.133847e-02
# 99882                         1.946377e-02
# 99883                         0.000000e+00
# 99884                         0.000000e+00
# 99885                         0.000000e+00
# 99886                         6.110757e-02
# 99887                         1.210045e-01
# 99888                         0.000000e+00
# 99889                         2.480374e-02
# 99890                         3.552714e-17
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         9.090069e-06
# 99894                         2.652728e-02
# 99895                         1.931875e-02
# 99896                         0.000000e+00
# 99897                         9.739978e-03
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_19  \
# 0                            -1.948808e-03
# 1                             1.502472e-03
# 2                            -5.021715e-04
# 3                            -1.813029e-04
# 4                            -6.030881e-05
# 5                            -3.031750e-04
# 6                            -7.539605e-05
# 7                             6.076352e-05
# 8                            -1.001448e-04
# 9                            -9.879404e-05
# 10                           -3.000711e-05
# 11                           -8.425498e-06
# 12                            4.550004e-06
# 13                            1.164945e-05
# 14                           -1.709587e-05
# 15                           -1.552470e-05
# 16                           -3.755201e-06
# 17                           -1.461559e-05
# 18                           -3.874937e-07
# 19                            4.822205e-05
# 20                           -1.717427e-05
# 21                            1.097296e-06
# 22                           -1.292811e-05
# 23                           -2.810870e-07
# 24                            1.892572e-06
# 25                            1.332644e-06
# 26                            3.177249e-06
# 27                            2.900689e-06
# 28                           -2.371642e-05
# 29                           -4.672575e-07
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                         0.000000e+00
# 99873                         0.000000e+00
# 99874                         0.000000e+00
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                        -6.781136e-09
# 99878                         0.000000e+00
# 99879                        -4.255879e-08
# 99880                         0.000000e+00
# 99881                         0.000000e+00
# 99882                         2.036702e-04
# 99883                         0.000000e+00
# 99884                         0.000000e+00
# 99885                         0.000000e+00
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         0.000000e+00
# 99890                         4.326057e-16
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         0.000000e+00
# 99894                         2.092841e-02
# 99895                         4.357530e-08
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_20  \
# 0                             5.954764e-04
# 1                             2.632841e-03
# 2                             2.035582e-04
# 3                             1.930283e-04
# 4                            -3.502922e-04
# 5                            -2.053146e-04
# 6                             9.535863e-05
# 7                             1.885005e-05
# 8                             2.744437e-05
# 9                            -4.755455e-04
# 10                            3.117573e-06
# 11                            1.104327e-05
# 12                           -2.016882e-05
# 13                            5.372544e-06
# 14                           -8.878957e-06
# 15                            3.943588e-07
# 16                           -8.989076e-07
# 17                           -2.972270e-05
# 18                            8.489901e-06
# 19                            1.121654e-04
# 20                           -2.766518e-05
# 21                            1.067976e-05
# 22                           -1.957167e-05
# 23                           -6.092467e-08
# 24                           -8.519422e-07
# 25                            3.763911e-05
# 26                           -5.855175e-06
# 27                            2.501298e-06
# 28                           -2.991786e-06
# 29                            6.216320e-06
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                         0.000000e+00
# 99873                         0.000000e+00
# 99874                         0.000000e+00
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                        -3.342269e-09
# 99878                         0.000000e+00
# 99879                        -6.984142e-08
# 99880                         0.000000e+00
# 99881                         0.000000e+00
# 99882                        -6.170026e-06
# 99883                         0.000000e+00
# 99884                         0.000000e+00
# 99885                         5.669339e-08
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         0.000000e+00
# 99890                        -5.833169e-11
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         0.000000e+00
# 99894                        -4.513222e-03
# 99895                        -4.362732e-08
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_21  \
# 0                            -6.010791e-04
# 1                             5.001386e-07
# 2                            -2.088172e-05
# 3                            -7.246957e-05
# 4                            -1.627311e-04
# 5                            -1.980552e-04
# 6                            -3.137577e-04
# 7                            -7.096050e-05
# 8                            -1.972243e-05
# 9                             1.107727e-04
# 10                           -8.343809e-05
# 11                           -7.743391e-06
# 12                            8.005491e-06
# 13                           -8.825387e-06
# 14                           -2.068452e-05
# 15                            1.824856e-07
# 16                           -2.936032e-08
# 17                           -1.399818e-05
# 18                           -2.044297e-05
# 19                           -5.095268e-05
# 20                            1.183772e-05
# 21                           -2.999344e-06
# 22                           -3.400685e-05
# 23                            7.552254e-07
# 24                           -5.290589e-06
# 25                           -8.214693e-06
# 26                           -1.770500e-05
# 27                           -2.434508e-06
# 28                           -1.980095e-05
# 29                           -3.803013e-06
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                         0.000000e+00
# 99873                         0.000000e+00
# 99874                         0.000000e+00
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                         0.000000e+00
# 99878                         0.000000e+00
# 99879                        -5.192677e-08
# 99880                         0.000000e+00
# 99881                         0.000000e+00
# 99882                         0.000000e+00
# 99883                         5.634921e-11
# 99884                         0.000000e+00
# 99885                         0.000000e+00
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         0.000000e+00
# 99890                        -7.040187e-07
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         0.000000e+00
# 99894                         8.500553e-03
# 99895                         0.000000e+00
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_22  \
# 0                             6.935239e-04
# 1                             7.223111e-04
# 2                             2.681181e-04
# 3                             8.203465e-05
# 4                             4.616092e-05
# 5                             1.061176e-04
# 6                             7.716252e-05
# 7                             4.974652e-06
# 8                             2.648740e-05
# 9                             3.406578e-05
# 10                            2.335735e-05
# 11                            8.533535e-07
# 12                            6.694437e-07
# 13                            1.006270e-06
# 14                            8.074013e-06
# 15                            5.576120e-06
# 16                           -1.424434e-06
# 17                            8.623818e-06
# 18                            1.097475e-05
# 19                            8.501119e-06
# 20                            2.017745e-05
# 21                            8.798746e-07
# 22                            3.827270e-05
# 23                            3.492656e-07
# 24                            3.123472e-06
# 25                            2.719522e-06
# 26                            3.535220e-06
# 27                            4.095880e-07
# 28                            1.687322e-05
# 29                            1.315278e-06
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                         0.000000e+00
# 99873                         0.000000e+00
# 99874                         0.000000e+00
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                         1.098390e-09
# 99878                         0.000000e+00
# 99879                        -1.677640e-09
# 99880                         0.000000e+00
# 99881                         0.000000e+00
# 99882                        -2.982389e-04
# 99883                        -1.204132e-11
# 99884                         0.000000e+00
# 99885                         1.223882e-07
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         0.000000e+00
# 99890                         0.000000e+00
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         0.000000e+00
# 99894                         0.000000e+00
# 99895                        -3.411640e-08
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_23  \
# 0                            -1.948808e-03
# 1                             1.502472e-03
# 2                            -5.021715e-04
# 3                            -1.813029e-04
# 4                            -6.030881e-05
# 5                            -3.031750e-04
# 6                            -7.539605e-05
# 7                             6.076352e-05
# 8                            -1.001448e-04
# 9                            -9.879404e-05
# 10                           -3.000711e-05
# 11                           -8.425498e-06
# 12                            4.550004e-06
# 13                            1.164945e-05
# 14                           -1.709587e-05
# 15                           -1.552470e-05
# 16                           -3.755201e-06
# 17                           -1.461559e-05
# 18                           -3.874937e-07
# 19                            4.822205e-05
# 20                           -1.717427e-05
# 21                            1.097296e-06
# 22                           -1.292811e-05
# 23                           -2.810870e-07
# 24                            1.892572e-06
# 25                            1.332644e-06
# 26                            3.177249e-06
# 27                            2.900689e-06
# 28                           -2.371642e-05
# 29                           -4.672575e-07
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                         0.000000e+00
# 99873                         0.000000e+00
# 99874                         0.000000e+00
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                        -6.781136e-09
# 99878                         0.000000e+00
# 99879                        -4.255879e-08
# 99880                         0.000000e+00
# 99881                         0.000000e+00
# 99882                         2.036702e-04
# 99883                         0.000000e+00
# 99884                         0.000000e+00
# 99885                         0.000000e+00
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         0.000000e+00
# 99890                         4.326057e-16
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         0.000000e+00
# 99894                         2.092841e-02
# 99895                         4.357530e-08
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
#        lazy_ber_drop_mlp_postSample_cov_24
# 0                             8.712331e-03
# 1                             5.760585e-03
# 2                             2.306879e-03
# 3                             1.656778e-04
# 4                             4.321356e-04
# 5                             5.343764e-04
# 6                             2.672547e-04
# 7                             8.389217e-06
# 8                             1.307236e-05
# 9                             7.937176e-05
# 10                            1.417778e-05
# 11                            7.245217e-07
# 12                            1.075079e-07
# 13                            1.556829e-07
# 14                            7.299640e-07
# 15                            1.594319e-06
# 16                            5.435339e-08
# 17                            4.070493e-06
# 18                            1.849037e-06
# 19                            2.475305e-05
# 20                            7.701002e-06
# 21                            1.286845e-07
# 22                            4.610545e-06
# 23                            3.592675e-09
# 24                            1.612403e-08
# 25                            4.261835e-07
# 26                            3.257878e-07
# 27                            6.543058e-09
# 28                            9.609294e-07
# 29                            8.933916e-08
# ...                                    ...
# 99869                         0.000000e+00
# 99870                         0.000000e+00
# 99871                         0.000000e+00
# 99872                         0.000000e+00
# 99873                         0.000000e+00
# 99874                         0.000000e+00
# 99875                         0.000000e+00
# 99876                         0.000000e+00
# 99877                         4.733103e-14
# 99878                         0.000000e+00
# 99879                         2.114451e-12
# 99880                         0.000000e+00
# 99881                         0.000000e+00
# 99882                         1.000000e-02
# 99883                         1.421085e-16
# 99884                         0.000000e+00
# 99885                         5.000386e-12
# 99886                         0.000000e+00
# 99887                         0.000000e+00
# 99888                         0.000000e+00
# 99889                         0.000000e+00
# 99890                         5.162911e-11
# 99891                         0.000000e+00
# 99892                         0.000000e+00
# 99893                         0.000000e+00
# 99894                         1.857921e-01
# 99895                         4.762962e-10
# 99896                         0.000000e+00
# 99897                         0.000000e+00
# 99898                         0.000000e+00
#
# [99899 rows x 25 columns]

# %%
data_df = pd.read_csv(path,  sep='\t')
data_df.columns
# Out:
# Index(['Step', 'MLPLoss', 'LazyBernDropPredError', 'LazyBernDropUnc',
#        'lazy_ber_drop_mlp_postSample_cov_0',
#        'lazy_ber_drop_mlp_postSample_cov_1',
#        'lazy_ber_drop_mlp_postSample_cov_2',
#        'lazy_ber_drop_mlp_postSample_cov_3',
#        'lazy_ber_drop_mlp_postSample_cov_4',
#        'lazy_ber_drop_mlp_postSample_cov_5',
#        'lazy_ber_drop_mlp_postSample_cov_6',
#        'lazy_ber_drop_mlp_postSample_cov_7',
#        'lazy_ber_drop_mlp_postSample_cov_8',
#        'lazy_ber_drop_mlp_postSample_cov_9',
#        'lazy_ber_drop_mlp_postSample_cov_10',
#        'lazy_ber_drop_mlp_postSample_cov_11',
#        'lazy_ber_drop_mlp_postSample_cov_12',
#        'lazy_ber_drop_mlp_postSample_cov_13',
#        'lazy_ber_drop_mlp_postSample_cov_14',
#        'lazy_ber_drop_mlp_postSample_cov_15',
#        'lazy_ber_drop_mlp_postSample_cov_16',
#        'lazy_ber_drop_mlp_postSample_cov_17',
#        'lazy_ber_drop_mlp_postSample_cov_18',
#        'lazy_ber_drop_mlp_postSample_cov_19',
#        'lazy_ber_drop_mlp_postSample_cov_20',
#        'lazy_ber_drop_mlp_postSample_cov_21',
#        'lazy_ber_drop_mlp_postSample_cov_22',
#        'lazy_ber_drop_mlp_postSample_cov_23',
#        'lazy_ber_drop_mlp_postSample_cov_24', 'BernDropPredError',
#        'BernDropUnc', 'ber_drop_mlp_postSample_cov_0',
#        'ber_drop_mlp_postSample_cov_1', 'ber_drop_mlp_postSample_cov_2',
#        'ber_drop_mlp_postSample_cov_3', 'ber_drop_mlp_postSample_cov_4',
#        'ber_drop_mlp_postSample_cov_5', 'ber_drop_mlp_postSample_cov_6',
#        'ber_drop_mlp_postSample_cov_7', 'ber_drop_mlp_postSample_cov_8',
#        'ber_drop_mlp_postSample_cov_9', 'ber_drop_mlp_postSample_cov_10',
#        'ber_drop_mlp_postSample_cov_11', 'ber_drop_mlp_postSample_cov_12',
#        'ber_drop_mlp_postSample_cov_13', 'ber_drop_mlp_postSample_cov_14',
#        'ber_drop_mlp_postSample_cov_15', 'ber_drop_mlp_postSample_cov_16',
#        'ber_drop_mlp_postSample_cov_17', 'ber_drop_mlp_postSample_cov_18',
#        'ber_drop_mlp_postSample_cov_19', 'ber_drop_mlp_postSample_cov_20',
#        'ber_drop_mlp_postSample_cov_21', 'ber_drop_mlp_postSample_cov_22',
#        'ber_drop_mlp_postSample_cov_23', 'ber_drop_mlp_postSample_cov_24',
#        'BernDropLoss', 'BootstrappedEnsemblePredError',
#        'BootstrappedEnsembleUnc', 'boots_ensemble_preds_cov_0',
#        'boots_ensemble_preds_cov_1', 'boots_ensemble_preds_cov_2',
#        'boots_ensemble_preds_cov_3', 'boots_ensemble_preds_cov_4',
#        'boots_ensemble_preds_cov_5', 'boots_ensemble_preds_cov_6',
#        'boots_ensemble_preds_cov_7', 'boots_ensemble_preds_cov_8',
#        'boots_ensemble_preds_cov_9', 'boots_ensemble_preds_cov_10',
#        'boots_ensemble_preds_cov_11', 'boots_ensemble_preds_cov_12',
#        'boots_ensemble_preds_cov_13', 'boots_ensemble_preds_cov_14',
#        'boots_ensemble_preds_cov_15', 'boots_ensemble_preds_cov_16',
#        'boots_ensemble_preds_cov_17', 'boots_ensemble_preds_cov_18',
#        'boots_ensemble_preds_cov_19', 'boots_ensemble_preds_cov_20',
#        'boots_ensemble_preds_cov_21', 'boots_ensemble_preds_cov_22',
#        'boots_ensemble_preds_cov_23', 'boots_ensemble_preds_cov_24',
#        'BootsEnsembleAvgLoss'],
#       dtype='object')

# %%
marker = '.'
markersize = 0.8

data_set_size = data_df['LazyBernDropPredError'].shape[0]#10000
training_steps = data_df['LazyBernDropPredError'].shape[0]

# Prediction error
f, axes = plt.subplots(1, 3, sharey=True)
f.set_figwidth(18)
f.set_figheight(4)

axes[0].plot(data_df['LazyBernDropPredError'], marker, markersize=markersize)
axes[0].set_title('Lazy Bernoulli Dropout Prediction Error')
axes[0].tick_params(axis='x', labelrotation=30)
axes[0].set_xlabel('Steps')
axes[0].set_ylabel('Prediction Error')
axes[0].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[0].text(data_set_size/2, 1.7, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center',wrap=True)
axes[0].text((training_steps-data_set_size)/2+data_set_size, 1.7, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)

axes[1].plot(data_df['BernDropPredError'], marker, markersize=markersize)
axes[1].set_title('Bernoulli Dropout Prediction Error')
axes[1].tick_params(axis='x', labelrotation=30)
axes[1].set_xlabel('Steps')
axes[1].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[1].text(data_set_size/2, 1.7, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[1].text((training_steps-data_set_size)/2+data_set_size, 1.7, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)

axes[2].plot(data_df['BootstrappedEnsemblePredError'], marker, markersize=markersize)
axes[2].set_title('Bootstrapped Ensemble Prediction Error')
axes[2].tick_params(axis='x', labelrotation=30)
axes[2].set_xlabel('Steps')
axes[2].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[2].text(data_set_size/2, 1.7, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[2].text((training_steps-data_set_size)/2+data_set_size, 1.7, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)
f.savefig('./realistic_example_collecting_at_beginning_pred_error.jpg', dpi=300)

# Loss
f, axes = plt.subplots(1, 3)
f.set_figwidth(18)
f.set_figheight(4)

axes[0].plot(data_df['MLPLoss'], marker, markersize=markersize)
axes[0].set_title('Lazy Bernoulli Dropout (MLP) Loss')
axes[0].tick_params(axis='x', labelrotation=30)
axes[0].set_xlabel('Steps')
axes[0].set_ylabel('Loss')
axes[0].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[0].text(data_set_size/2, 0.3, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[0].text((training_steps-data_set_size)/2+data_set_size, 0.3, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)

axes[1].plot(data_df['BernDropLoss'], marker, markersize=markersize)
axes[1].set_title('Bernoulli Dropout Loss')
axes[1].tick_params(axis='x', labelrotation=30)
axes[1].set_xlabel('Steps')
axes[1].set_ylabel('Loss')
axes[1].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[1].text(data_set_size/2, 100, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[1].text((training_steps-data_set_size)/2+data_set_size, 100, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)

axes[2].plot(data_df['BootsEnsembleAvgLoss'], marker, markersize=markersize)
axes[2].set_title('Bootstrapped Ensemble Loss')
axes[2].tick_params(axis='x', labelrotation=30)
axes[2].set_xlabel('Steps')
axes[2].set_ylabel('Loss')
axes[2].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[2].text(data_set_size/2, 0.25, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[2].text((training_steps-data_set_size)/2+data_set_size, 0.25, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)
f.savefig('./realistic_example_collecting_at_beginning_loss.jpg', dpi=300)

# Uncertainty
f, axes = plt.subplots(1, 3, sharey=True)
f.set_figwidth(18)
f.set_figheight(4)

axes[0].plot(data_df['LazyBernDropUnc'], marker, markersize=markersize)
axes[0].set_title('Lazy Bernoulli Dropout Uncertainty')
axes[0].tick_params(axis='x', labelrotation=30)
axes[0].set_xlabel('Steps')
axes[0].set_ylabel('Uncertainty')
axes[0].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[0].text(data_set_size/2, 0.5, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[0].text((training_steps-data_set_size)/2+data_set_size, 0.5, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)

axes[1].plot(data_df['BernDropUnc'], marker, markersize=markersize)
axes[1].set_title('Bernoulli Dropout Uncertainty')
axes[1].tick_params(axis='x', labelrotation=30)
axes[1].set_xlabel('Steps')
axes[1].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[1].text(data_set_size/2, 0.5, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[1].text((training_steps-data_set_size)/2+data_set_size, 0.5, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)

axes[2].plot(data_df['BootstrappedEnsembleUnc'], marker, markersize=markersize)
axes[2].set_title('Bootstrapped Ensemble Uncertainty')
axes[2].tick_params(axis='x', labelrotation=30)
axes[2].set_xlabel('Steps')
axes[2].axvline(x=data_set_size, linestyle='--', linewidth=2, color='r')
axes[2].text(data_set_size/2, 0.5, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
axes[2].text((training_steps-data_set_size)/2+data_set_size, 0.5, 'Only Training', fontsize=12, ha='center', va='center', wrap=True)
f.savefig('./realistic_example_collecting_at_beginning_uncertainty.jpg', dpi=300)

# Uncertainty Histogram
f, axes = plt.subplots(1, 3, sharey=True, sharex=True)
f.set_figwidth(18)
f.set_figheight(3)
num_bins=50
axes[0].hist(data_df['LazyBernDropUnc'], num_bins, facecolor='blue', alpha=0.5)
axes[0].set_xlabel('Uncertainty')
axes[0].set_ylabel('Count')
axes[0].set_title('Lazy Bernoulli Dropout Uncertainty Histogram')

axes[1].hist(data_df['BernDropUnc'], num_bins, facecolor='blue', alpha=0.5)
axes[1].set_xlabel('Uncertainty')
axes[1].set_title('Bernoulli Dropout Uncertaity Histogram')

axes[2].hist(data_df['BootstrappedEnsembleUnc'], num_bins, facecolor='blue', alpha=0.5)
axes[2].set_xlabel('Uncertainty')
axes[2].set_title('Bootstrapped Ensemble Uncertainty Histogram')
f.savefig('./realistic_example_collecting_at_beginning_uncertainty_hist.jpg', dpi=300)

# %% [markdown]
# # Training and Collecting Every Time Step

# %%
path = r"C:\Users\pc-admin\Github Repos\spinup_data\2019-05-27_uncertainty_estimate\2019-05-27_22-39-33-uncertainty_estimate_s3\progress.txt"

# %%
data_df = pd.read_csv(path,  sep='\t')
data_df.columns
# Out:
# Index(['Step', 'MLPLoss', 'LazyBernDropPredError', 'LazyBernDropUnc',
#        'lazy_ber_drop_mlp_postSample_cov_0',
#        'lazy_ber_drop_mlp_postSample_cov_1',
#        'lazy_ber_drop_mlp_postSample_cov_2',
#        'lazy_ber_drop_mlp_postSample_cov_3',
#        'lazy_ber_drop_mlp_postSample_cov_4',
#        'lazy_ber_drop_mlp_postSample_cov_5',
#        'lazy_ber_drop_mlp_postSample_cov_6',
#        'lazy_ber_drop_mlp_postSample_cov_7',
#        'lazy_ber_drop_mlp_postSample_cov_8',
#        'lazy_ber_drop_mlp_postSample_cov_9',
#        'lazy_ber_drop_mlp_postSample_cov_10',
#        'lazy_ber_drop_mlp_postSample_cov_11',
#        'lazy_ber_drop_mlp_postSample_cov_12',
#        'lazy_ber_drop_mlp_postSample_cov_13',
#        'lazy_ber_drop_mlp_postSample_cov_14',
#        'lazy_ber_drop_mlp_postSample_cov_15',
#        'lazy_ber_drop_mlp_postSample_cov_16',
#        'lazy_ber_drop_mlp_postSample_cov_17',
#        'lazy_ber_drop_mlp_postSample_cov_18',
#        'lazy_ber_drop_mlp_postSample_cov_19',
#        'lazy_ber_drop_mlp_postSample_cov_20',
#        'lazy_ber_drop_mlp_postSample_cov_21',
#        'lazy_ber_drop_mlp_postSample_cov_22',
#        'lazy_ber_drop_mlp_postSample_cov_23',
#        'lazy_ber_drop_mlp_postSample_cov_24', 'BernDropPredError',
#        'BernDropUnc', 'ber_drop_mlp_postSample_cov_0',
#        'ber_drop_mlp_postSample_cov_1', 'ber_drop_mlp_postSample_cov_2',
#        'ber_drop_mlp_postSample_cov_3', 'ber_drop_mlp_postSample_cov_4',
#        'ber_drop_mlp_postSample_cov_5', 'ber_drop_mlp_postSample_cov_6',
#        'ber_drop_mlp_postSample_cov_7', 'ber_drop_mlp_postSample_cov_8',
#        'ber_drop_mlp_postSample_cov_9', 'ber_drop_mlp_postSample_cov_10',
#        'ber_drop_mlp_postSample_cov_11', 'ber_drop_mlp_postSample_cov_12',
#        'ber_drop_mlp_postSample_cov_13', 'ber_drop_mlp_postSample_cov_14',
#        'ber_drop_mlp_postSample_cov_15', 'ber_drop_mlp_postSample_cov_16',
#        'ber_drop_mlp_postSample_cov_17', 'ber_drop_mlp_postSample_cov_18',
#        'ber_drop_mlp_postSample_cov_19', 'ber_drop_mlp_postSample_cov_20',
#        'ber_drop_mlp_postSample_cov_21', 'ber_drop_mlp_postSample_cov_22',
#        'ber_drop_mlp_postSample_cov_23', 'ber_drop_mlp_postSample_cov_24',
#        'BernDropLoss', 'BootstrappedEnsemblePredError',
#        'BootstrappedEnsembleUnc', 'boots_ensemble_preds_cov_0',
#        'boots_ensemble_preds_cov_1', 'boots_ensemble_preds_cov_2',
#        'boots_ensemble_preds_cov_3', 'boots_ensemble_preds_cov_4',
#        'boots_ensemble_preds_cov_5', 'boots_ensemble_preds_cov_6',
#        'boots_ensemble_preds_cov_7', 'boots_ensemble_preds_cov_8',
#        'boots_ensemble_preds_cov_9', 'boots_ensemble_preds_cov_10',
#        'boots_ensemble_preds_cov_11', 'boots_ensemble_preds_cov_12',
#        'boots_ensemble_preds_cov_13', 'boots_ensemble_preds_cov_14',
#        'boots_ensemble_preds_cov_15', 'boots_ensemble_preds_cov_16',
#        'boots_ensemble_preds_cov_17', 'boots_ensemble_preds_cov_18',
#        'boots_ensemble_preds_cov_19', 'boots_ensemble_preds_cov_20',
#        'boots_ensemble_preds_cov_21', 'boots_ensemble_preds_cov_22',
#        'boots_ensemble_preds_cov_23', 'boots_ensemble_preds_cov_24',
#        'BootsEnsembleAvgLoss'],
#       dtype='object')

# %%
marker = '.'
markersize = 0.5

data_set_size = data_df['LazyBernDropPredError'].shape[0]

# Prediction error
f, axes = plt.subplots(1, 3, sharey=True)
f.set_figwidth(18)
f.set_figheight(4)

axes[0].plot(data_df['LazyBernDropPredError'], marker, markersize=markersize)
axes[0].set_title('Lazy Bernoulli Dropout Prediction Error')
axes[0].tick_params(axis='x', labelrotation=30)
axes[0].set_xlabel('Steps')
axes[0].set_ylabel('Prediction Error')
axes[0].text(data_set_size/2, 1.7, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center',wrap=True)

axes[1].plot(data_df['BernDropPredError'], marker, markersize=markersize)
axes[1].set_title('Bernoulli Dropout Prediction Error')
axes[1].tick_params(axis='x', labelrotation=30)
axes[1].set_xlabel('Steps')
axes[1].text(data_set_size/2, 1.7, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)

axes[2].plot(data_df['BootstrappedEnsemblePredError'], marker, markersize=markersize)
axes[2].set_title('Bootstrapped Ensemble Prediction Error')
axes[2].tick_params(axis='x', labelrotation=30)
axes[2].set_xlabel('Steps')
axes[2].text(data_set_size/2, 1.7, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)

f.savefig('./realistic_example_training_and_collecting_pred_error.jpg', dpi=300)

# Loss
f, axes = plt.subplots(1, 3)
f.set_figwidth(18)
f.set_figheight(4)

axes[0].plot(data_df['MLPLoss'], marker, markersize=markersize)
axes[0].set_title('Lazy Bernoulli Dropout (MLP) Loss')
axes[0].tick_params(axis='x', labelrotation=30)
axes[0].set_xlabel('Steps')
axes[0].set_ylabel('Loss')
axes[0].text(data_set_size/2, 0.3, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)

axes[1].plot(data_df['BernDropLoss'], marker, markersize=markersize)
axes[1].set_title('Bernoulli Dropout Loss')
axes[1].tick_params(axis='x', labelrotation=30)
axes[1].set_xlabel('Steps')
axes[1].set_ylabel('Loss')
axes[1].text(data_set_size/2, 100, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)

axes[2].plot(data_df['BootsEnsembleAvgLoss'], marker, markersize=markersize)
axes[2].set_title('Bootstrapped Ensemble Loss')
axes[2].tick_params(axis='x', labelrotation=30)
axes[2].set_xlabel('Steps')
axes[2].set_ylabel('Loss')
axes[2].text(data_set_size/2, 0.25, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
f.savefig('./realistic_example_training_and_collecting_loss.jpg', dpi=300)

# Uncertainty
f, axes = plt.subplots(1, 3, sharey=True)
f.set_figwidth(18)
f.set_figheight(4)

axes[0].plot(data_df['LazyBernDropUnc'], marker, markersize=markersize)
axes[0].set_title('Lazy Bernoulli Dropout Uncertainty')
axes[0].tick_params(axis='x', labelrotation=30)
axes[0].set_xlabel('Steps')
axes[0].set_ylabel('Uncertainty')
axes[0].text(data_set_size/2, 0.8, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)

axes[1].plot(data_df['BernDropUnc'], marker, markersize=markersize)
axes[1].set_title('Bernoulli Dropout Uncertainty')
axes[1].tick_params(axis='x', labelrotation=30)
axes[1].set_xlabel('Steps')
axes[1].text(data_set_size/2, 0.8, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)

axes[2].plot(data_df['BootstrappedEnsembleUnc'], marker, markersize=markersize)
axes[2].set_title('Bootstrapped Ensemble Uncertainty')
axes[2].tick_params(axis='x', labelrotation=30)
axes[2].set_xlabel('Steps')
axes[2].text(data_set_size/2, 0.8, 'Data Collecting\n& Training', fontsize=12, ha='center', va='center', wrap=True)
f.savefig('./realistic_example_training_and_collecting_uncertainty.jpg', dpi=300)

# Uncertainty Histogram
f, axes = plt.subplots(1, 3, sharey=True, sharex=True)
f.set_figwidth(18)
f.set_figheight(3)
num_bins=50
axes[0].hist(data_df['LazyBernDropUnc'], num_bins, facecolor='blue', alpha=0.5)
axes[0].set_xlabel('Uncertainty')
axes[0].set_ylabel('Count')
axes[0].set_title('Lazy Bernoulli Dropout Uncertainty Histogram')

axes[1].hist(data_df['BernDropUnc'], num_bins, facecolor='blue', alpha=0.5)
axes[1].set_xlabel('Uncertainty')
axes[1].set_title('Bernoulli Dropout Uncertaity Histogram')

axes[2].hist(data_df['BootstrappedEnsembleUnc'], num_bins, facecolor='blue', alpha=0.5)
axes[2].set_xlabel('Uncertainty')
axes[2].set_title('Bootstrapped Ensemble Uncertainty Histogram')
f.savefig('./realistic_example_training_and_collecting_uncertainty_hist.jpg', dpi=300)

# %% [markdown]
# ## Not used

# %%
stages = int(data_df['LazyBernDropUnc'].shape[0] / 2000)
stages
# Out:
# 2

# %%
stages = 20

f, axes = plt.subplots(stages, 3, sharey=True, sharex=True)
f.set_figwidth(18)
f.set_figheight(stages*3)
for i in range(stages):
    num_bins=50
    axes[i][0].hist(data_df['LazyBernDropUnc'][i*2000:(i+1)*2000], num_bins, facecolor='blue', alpha=0.5)
    axes[i][0].set_title('LazyBernDropUnc: [step_{} , step_{}]'.format(i*2000,(i+1)*2000))

    axes[i][1].hist(data_df['BernDropUnc'][i*2000:(i+1)*2000], num_bins, facecolor='blue', alpha=0.5)
    axes[i][1].set_title('BernDropUnc: [step_{} , step_{}]'.format(i*2000,(i+1)*2000))

    axes[i][2].hist(data_df['BootstrappedEnsembleUnc'][i*2000:(i+1)*2000], num_bins, facecolor='blue', alpha=0.5)
    axes[i][2].set_title('BootstrappedEnsembleUnc: [step_{} , step_{}]'.format(i*2000,(i+1)*2000))

f.savefig('./realistic_example_uncertainty_hist_change.jpg', dpi=300)
